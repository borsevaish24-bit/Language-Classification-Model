# %%
pip install wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 850.4 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 415.0 kB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -c "import wandb; print(wandb.__version__)"
# Out:
# 0.24.1

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
# !python train_model.py
# Out:
# Current time: 20260202_190540
# Traceback (most recent call last):
#   File "/Users/tejas_borse/Desktop/Winter 2025/NNTI/Project/train_model.py", line 17, in <module>
#     from datasets import (
#   File "/opt/anaconda3/lib/python3.12/site-packages/datasets/__init__.py", line 17, in <module>
#     from .arrow_dataset import Dataset
#   File "/opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py", line 73, in <module>
#     from .arrow_reader import ArrowReader
#   File "/opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_reader.py", line 27, in <module>
#     import pyarrow.parquet as pq
#   File "/opt/anaconda3/lib/python3.12/site-packages/pyarrow/parquet/__init__.py", line 20, in <module>
#     from .core import *
#   File "/opt/anaconda3/lib/python3.12/site-packages/pyarrow/parquet/core.py", line 52, in <module>
#     from pyarrow.fs import (LocalFileSystem, FileSystem, FileType,
# ...
